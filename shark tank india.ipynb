# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Shark_Tank_India.csv")
df.head(10)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
# 5               2             6         Agro tourism
# 6               3             7          Qzense Labs
# 7               3             8            Peeschute
# 8               3             9                 NOCD
# 9               4            10                Cosiq
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
# 2                             Detachable Sleeves     1                25.0
# 3                           Healthy Potato Chips     1                70.0
# ...

# %%
print("shape of data: ", df.shape)
# Out:
# shape of data:  (117, 28)

# %%
df.columns
# Out:
# Index(['episode_number', 'pitch_number', 'brand_name', 'idea', 'deal',
#        'pitcher_ask_amount', 'ask_equity', 'ask_valuation', 'deal_amount',
#        'deal_equity', 'deal_valuation', 'ashneer_present', 'anupam_present',
#        'aman_present', 'namita_present', 'vineeta_present', 'peyush_present',
#        'ghazal_present', 'ashneer_deal', 'anupam_deal', 'aman_deal',
#        'namita_deal', 'vineeta_deal', 'peyush_deal', 'ghazal_deal',
#        'total_sharks_invested', 'amount_per_shark', 'equity_per_shark'],
#       dtype='object')

# %%
print("shape of data: ", df.shape)
# Out:
# shape of data:  (117, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %%
df.isnull().any()
# Out:
# episode_number           False
# pitch_number             False
# brand_name               False
# idea                     False
# deal                     False
# pitcher_ask_amount       False
# ask_equity               False
# ask_valuation            False
# deal_amount              False
# deal_equity              False
# deal_valuation           False
# ashneer_present          False
# anupam_present           False
# aman_present             False
# namita_present           False
# vineeta_present          False
# peyush_present           False
# ghazal_present           False
# ashneer_deal             False
# anupam_deal              False
# aman_deal                False
# namita_deal              False
# vineeta_deal             False
# peyush_deal              False
# ghazal_deal              False
# total_sharks_invested    False
# amount_per_shark         False
# equity_per_shark         False
# dtype: bool

# %%
df.describe()
# Out:
#        episode_number  pitch_number        deal  pitcher_ask_amount  \
# count      117.000000    117.000000  117.000000          117.000000
# mean        18.735043     59.000000    0.555556          319.854709
# std         10.070778     33.919021    0.499041         2767.842777
# min          1.000000      1.000000    0.000000            0.001010
# 25%         10.000000     30.000000    0.000000           45.000000
# 50%         19.000000     59.000000    1.000000           50.000000
# 75%         27.000000     88.000000    1.000000           80.000000
# max         35.000000    117.000000    1.000000        30000.000000
#
#        ask_equity  ask_valuation  deal_amount  deal_equity  deal_valuation  \
# count  117.000000     117.000000   117.000000   117.000000      117.000000
# mean     5.188034    3852.462479    31.982915     8.963504      467.104872
# std      3.892121   11931.601957    36.687391    13.106769      919.988864
# ...

# %% [markdown]
# # percantage of compnies got investment or not.

# %%
got=df[df["deal_amount"]>0.0].shape[0]
not_in=df[df["deal_amount"]==0.0].shape[0]
values=[got,not_in]
plt.pie(values,labels=["Got investment"," Not Recieved Investment"],autopct='%1.1f%%',startangle=35)
plt.title("Number of companies which got INvestment or Not -")
plt.show()

# %% [markdown]
# ## shark deals -

# %%
sharks = df[df["total_sharks_invested"]==5]
sharks = sharks.sort_values(by='deal_amount',ascending=False)
plt.figure(figsize=(10,7))
sns.set(style='darkgrid')
sns.barplot(data=sharks,x="brand_name",y="deal_amount",palette="viridis",color='pitcher_ask_amount')
plt.xlabel("Brand Name")
plt.ylabel("Deal Amount")
plt.title("5 Sharks Deals And Total Investment")
plt.xticks(rotation=60,ha='right')
plt.show()

# %% [markdown]
# ## Highest Pitch Ask Amount:

# %%
high = df[df["pitcher_ask_amount"] > 100]
plt.figure(figsize=(12, 8))
sns.barplot(x='brand_name', y='pitcher_ask_amount', data=high, hue='pitcher_ask_amount', palette='viridis')
plt.title("Highest Pitch Ask Amount:")
plt.show()

# %% [markdown]
# ## Least pitch amount:

# %%
least=df[df["pitcher_ask_amount"]<20]
plt.figure(figsize=(10,8))
sns.set_theme(style="dark")
sns.barplot(x="brand_name",y="pitcher_ask_amount",data=least,hue="pitcher_ask_amount",palette="viridis")
plt.title("least pitcher ask amount")
plt.show()

# %% [markdown]
# ## Ask Equity and Deal Equity:

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='brand_name', y='ask_equity', data=high, hue='ask_equity', palette='dark')
plt.title("Ask Equity & Deal Equity of Highest Pitch Ask Amount Brand:")
plt.show()

# %% [markdown]
# ## Each shark invested in deals:

# %%
deals=[df["ashneer_deal"].sum(),df["anupam_deal"].sum(),df["aman_deal"].sum(),
       df["namita_deal"].sum(),df["vineeta_deal"].sum(),df["ghazal_deal"].sum(),
      df["peyush_deal"].sum()]
columns=["ashneer","anupam","aman","namita","vineeta","ghazal","peyush"]
plt.figure(figsize=(12,8))
sns.barplot(sharks,x=columns,y=deals,hue=deals,width=0.96)
plt.xlabel("shark Names")
plt.ylabel("deals Values")
plt.title("Sharks Invested In deals")
plt.show()
